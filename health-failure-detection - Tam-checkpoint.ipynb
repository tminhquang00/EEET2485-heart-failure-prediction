# %% [markdown]
# # HEART FAILURE PREDICTION

# %%
# Data clearnning and EDA
import pandas as pd
import numpy as np
import math
import json
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
cd C:\Users\PC\OneDrive - RMIT University\Desktop\Reasearch Methods\Group assignment\EEET2485-heart-failure-prediction-main
# Out:
# C:\Users\PC\OneDrive - RMIT University\Desktop\Reasearch Methods\Group assignment\EEET2485-heart-failure-prediction-main

# %%
data = pd.read_csv('data/heart_failure_clinical_records_dataset.csv')

# %%
categorical_features = ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking', 'DEATH_EVENT']
numerical_features = ['age', 'creatinine_phosphokinase', 'ejection_fraction', 'platelets', 'serum_creatinine', 'serum_sodium', 'time']
health_features = ['anaemia', 'diabetes', 'high_blood_pressure', 'smoking', 'creatinine_phosphokinase', 'ejection_fraction', 'platelets', 'serum_creatinine', 'serum_sodium']

# %% [markdown]
# #### 3. The patients’ age and sex affect the health indicators

# %% [markdown]
# ##### ANOVA of age and sex with each health indicator

# %%
for feature in health_features:
    results = smf.ols(feature + ' ~ age + sex', data=data).fit()
    print('\033[1m ANOVA of age and sex with', feature,'\033[0m')
    print(results.summary())
    print('\n')
# Out:
#  ANOVA of age and sex with anaemia
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                anaemia   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     2.697
# Date:                Thu, 20 May 2021   Prob (F-statistic):             0.0691
# Time:                        21:03:05   Log-Likelihood:                -211.47
# No. Observations:                 299   AIC:                             428.9
# Df Residuals:                     296   BIC:                             440.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2594      0.152      1.709      0.089      -0.039       0.558
# age            0.0039      0.002      1.639      0.102      -0.001       0.009
# sex           -0.1048      0.060     -1.749      0.081      -0.223       0.013
# ==============================================================================
# Omnibus:                     1574.476   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.492
# Skew:                           0.269   Prob(JB):                     8.02e-11
# Kurtosis:                       1.145   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of age and sex with diabetes
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               diabetes   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     5.073
# Date:                Thu, 20 May 2021   Prob (F-statistic):            0.00682
# Time:                        21:03:05   Log-Likelihood:                -207.90
# No. Observations:                 299   AIC:                             421.8
# Df Residuals:                     296   BIC:                             432.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7500      0.150      5.001      0.000       0.455       1.045
# age           -0.0038      0.002     -1.590      0.113      -0.008       0.001
# sex           -0.1568      0.059     -2.650      0.008      -0.273      -0.040
# ==============================================================================
# Omnibus:                     1751.694   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.651
# Skew:                           0.319   Prob(JB):                     3.32e-10
# Kurtosis:                       1.241   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of age and sex with high_blood_pressure
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     high_blood_pressure   R-squared:                       0.021
# Model:                             OLS   Adj. R-squared:                  0.014
# Method:                  Least Squares   F-statistic:                     3.177
# Date:                 Thu, 20 May 2021   Prob (F-statistic):             0.0431
# Time:                         21:03:05   Log-Likelihood:                -199.97
# No. Observations:                  299   AIC:                             405.9
# Df Residuals:                      296   BIC:                             417.0
# Df Model:                            2
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1774      0.146      1.215      0.225      -0.110       0.465
# age            0.0040      0.002      1.745      0.082      -0.001       0.009
# sex           -0.1112      0.058     -1.929      0.055      -0.225       0.002
# ==============================================================================
# Omnibus:                     2854.100   Durbin-Watson:                   1.827
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.816
# Skew:                           0.602   Prob(JB):                     4.14e-11
# Kurtosis:                       1.455   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of age and sex with smoking
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                smoking   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     36.75
# Date:                Thu, 20 May 2021   Prob (F-statistic):           5.54e-15
# Time:                        21:03:05   Log-Likelihood:                -163.36
# No. Observations:                 299   AIC:                             332.7
# Df Residuals:                     296   BIC:                             343.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0629      0.129      0.487      0.627      -0.191       0.317
# age           -0.0004      0.002     -0.202      0.840      -0.004       0.004
# sex            0.4368      0.051      8.566      0.000       0.336       0.537
# ==============================================================================
# Omnibus:                      303.078   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.444
# Skew:                           0.278   Prob(JB):                     4.92e-06
# Kurtosis:                       1.714   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of age and sex with creatinine_phosphokinase
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     creatinine_phosphokinase   R-squared:                       0.014
# Model:                                  OLS   Adj. R-squared:                  0.007
# Method:                       Least Squares   F-statistic:                     2.091
# Date:                      Thu, 20 May 2021   Prob (F-statistic):              0.125
# Time:                              21:03:05   Log-Likelihood:                -2478.1
# No. Observations:                       299   AIC:                             4962.
# Df Residuals:                           296   BIC:                             4973.
# Df Model:                                 2
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    901.8786    297.408      3.032      0.003     316.576    1487.181
# age           -7.1113      4.718     -1.507      0.133     -16.397       2.174
# sex          173.4953    117.378      1.478      0.140     -57.506     404.497
# ==============================================================================
# Omnibus:                      302.533   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8100.706
# Skew:                           4.351   Prob(JB):                         0.00
# Kurtosis:                      26.968   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of age and sex with ejection_fraction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      ejection_fraction   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     4.093
# Date:                Thu, 20 May 2021   Prob (F-statistic):             0.0176
# Time:                        21:03:05   Log-Likelihood:                -1158.5
# No. Observations:                 299   AIC:                             2323.
# Df Residuals:                     296   BIC:                             2334.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.2969      3.604     10.072      0.000      29.205      43.389
# age            0.0698      0.057      1.220      0.223      -0.043       0.182
# sex           -3.7864      1.422     -2.662      0.008      -6.585      -0.987
# ==============================================================================
# Omnibus:                       12.775   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.646
# Skew:                           0.523   Prob(JB):                      0.00109
# Kurtosis:                       2.967   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of age and sex with platelets
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              platelets   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     2.654
# Date:                Thu, 20 May 2021   Prob (F-statistic):             0.0721
# Time:                        21:03:05   Log-Likelihood:                -3856.8
# No. Observations:                 299   AIC:                             7720.
# Df Residuals:                     296   BIC:                             7731.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.018e+05   2.99e+04     10.085      0.000    2.43e+05    3.61e+05
# age         -364.7280    474.708     -0.768      0.443   -1298.959     569.503
# sex          -2.5e+04   1.18e+04     -2.117      0.035   -4.82e+04   -1758.814
# ==============================================================================
# Omnibus:                      110.363   Durbin-Watson:                   2.215
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              557.324
# Skew:                           1.443   Prob(JB):                    9.52e-122
# Kurtosis:                       9.034   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of age and sex with serum_creatinine
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       serum_creatinine   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     3.850
# Date:                Thu, 20 May 2021   Prob (F-statistic):             0.0224
# Time:                        21:03:05   Log-Likelihood:                -430.07
# No. Observations:                 299   AIC:                             866.1
# Df Residuals:                     296   BIC:                             877.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5553      0.315      1.761      0.079      -0.065       1.176
# age            0.0139      0.005      2.772      0.006       0.004       0.024
# sex           -0.0075      0.124     -0.060      0.952      -0.252       0.237
# ==============================================================================
# Omnibus:                      309.745   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9241.991
# Skew:                           4.468   Prob(JB):                         0.00
# Kurtosis:                      28.729   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of age and sex with serum_sodium
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           serum_sodium   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.4034
# Date:                Thu, 20 May 2021   Prob (F-statistic):              0.668
# Time:                        21:03:05   Log-Likelihood:                -867.20
# No. Observations:                 299   AIC:                             1740.
# Df Residuals:                     296   BIC:                             1752.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    137.7740      1.360    101.292      0.000     135.097     140.451
# age           -0.0165      0.022     -0.762      0.446      -0.059       0.026
# sex           -0.2276      0.537     -0.424      0.672      -1.284       0.829
# ==============================================================================
# Omnibus:                       76.370   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              274.040
# Skew:                          -1.059   Prob(JB):                     3.11e-60
# Kurtosis:                       7.185   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 4. Do health indices affect the mortality rate of patients?

# %% [markdown]
# ##### All health indices affect the mortality rate

# %%
results = smf.ols('DEATH_EVENT ~ anaemia + diabetes + high_blood_pressure + sex + smoking + age + creatinine_phosphokinase + ' +
                  'ejection_fraction + platelets + serum_creatinine + serum_sodium + time', data=data).fit()
print(results.summary())
print('\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     17.04
# Date:                Thu, 20 May 2021   Prob (F-statistic):           2.35e-27
# Time:                        21:03:05   Log-Likelihood:                -115.90
# No. Observations:                 299   AIC:                             257.8
# Df Residuals:                     286   BIC:                             305.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    1.6636      0.695      2.392      0.017       0.295       3.032
# anaemia                     -0.0028      0.044     -0.062      0.950      -0.090       0.085
# diabetes                     0.0193      0.044      0.437      0.662      -0.068       0.106
# high_blood_pressure         -0.0143      0.046     -0.313      0.754      -0.104       0.076
# sex                         -0.0637      0.051     -1.247      0.214      -0.164       0.037
# smoking                     -0.0057      0.051     -0.112      0.911      -0.106       0.095
# age                          0.0058      0.002      3.088      0.002       0.002       0.009
# creatinine_phosphokinase  3.427e-05   2.25e-05      1.525      0.128   -9.96e-06    7.85e-05
# ejection_fraction           -0.0098      0.002     -5.333      0.000      -0.013      -0.006
# platelets                 -8.37e-08   2.21e-07     -0.379      0.705   -5.18e-07    3.51e-07
# serum_creatinine             0.0853      0.021      4.017      0.000       0.043       0.127
# serum_sodium                -0.0076      0.005     -1.513      0.131      -0.017       0.002
# time                        -0.0027      0.000     -9.415      0.000      -0.003      -0.002
# ==============================================================================
# Omnibus:                       10.068   Durbin-Watson:                   1.578
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                8.014
# Skew:                           0.306   Prob(JB):                       0.0182
# Kurtosis:                       2.483   Cond. No.                     9.26e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.26e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ##### Each health indice affects the mortality rate on its own

# %%
for feature in data.columns[:12]:
    results = smf.ols('DEATH_EVENT ~ ' + feature, data=data).fit()
    print('\033[1m ANOVA of',feature,'with DEATH_EVENT \033[0m')
    print(results.summary())
    print('\n')
# Out:
#  ANOVA of age with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     20.44
# Date:                Thu, 20 May 2021   Prob (F-statistic):           8.92e-06
# Time:                        21:03:05   Log-Likelihood:                -186.58
# No. Observations:                 299   AIC:                             377.2
# Df Residuals:                     297   BIC:                             384.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2858      0.137     -2.090      0.038      -0.555      -0.017
# age            0.0100      0.002      4.521      0.000       0.006       0.014
# ==============================================================================
# Omnibus:                      170.814   Durbin-Watson:                   1.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.004
# Skew:                           0.729   Prob(JB):                     2.78e-10
# Kurtosis:                       1.814   Cond. No.                         324.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of anaemia with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.310
# Date:                Thu, 20 May 2021   Prob (F-statistic):              0.253
# Time:                        21:03:05   Log-Likelihood:                -195.87
# No. Observations:                 299   AIC:                             395.7
# Df Residuals:                     297   BIC:                             403.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2941      0.036      8.204      0.000       0.224       0.365
# anaemia        0.0625      0.055      1.145      0.253      -0.045       0.170
# ==============================================================================
# Omnibus:                     1367.345   Durbin-Watson:                   1.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.310
# Skew:                           0.762   Prob(JB):                     2.65e-12
# Kurtosis:                       1.600   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of creatinine_phosphokinase with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.173
# Date:                Thu, 20 May 2021   Prob (F-statistic):              0.280
# Time:                        21:03:05   Log-Likelihood:                -195.93
# No. Observations:                 299   AIC:                             395.9
# Df Residuals:                     297   BIC:                             403.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.3035      0.032      9.622      0.000       0.241       0.366
# creatinine_phosphokinase  3.023e-05   2.79e-05      1.083      0.280   -2.47e-05    8.52e-05
# ==============================================================================
# Omnibus:                     1220.392   Durbin-Watson:                   1.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.603
# Skew:                           0.768   Prob(JB):                     2.29e-12
# Kurtosis:                       1.605   Cond. No.                     1.32e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ANOVA of diabetes with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                  0.001121
# Date:                Thu, 20 May 2021   Prob (F-statistic):              0.973
# Time:                        21:03:05   Log-Likelihood:                -196.52
# No. Observations:                 299   AIC:                             397.0
# Df Residuals:                     297   BIC:                             404.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3218      0.036      9.062      0.000       0.252       0.392
# diabetes      -0.0018      0.055     -0.033      0.973      -0.110       0.106
# ==============================================================================
# Omnibus:                     1981.981   Durbin-Watson:                   1.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.133
# Skew:                           0.766   Prob(JB):                     1.76e-12
# Kurtosis:                       1.588   Cond. No.                         2.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of ejection_fraction with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     23.09
# Date:                Thu, 20 May 2021   Prob (F-statistic):           2.45e-06
# Time:                        21:03:05   Log-Likelihood:                -185.33
# No. Observations:                 299   AIC:                             374.7
# Df Residuals:                     297   BIC:                             382.1
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.7253      0.088      8.235      0.000       0.552       0.899
# ejection_fraction    -0.0106      0.002     -4.806      0.000      -0.015      -0.006
# ==============================================================================
# Omnibus:                      147.000   Durbin-Watson:                   1.114
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.084
# Skew:                           0.728   Prob(JB):                     4.41e-10
# Kurtosis:                       1.843   Cond. No.                         135.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of high_blood_pressure with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.882
# Date:                Thu, 20 May 2021   Prob (F-statistic):              0.171
# Time:                        21:03:05   Log-Likelihood:                -195.58
# No. Observations:                 299   AIC:                             395.2
# Df Residuals:                     297   BIC:                             402.6
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.2938      0.034      8.763      0.000       0.228       0.360
# high_blood_pressure     0.0776      0.057      1.372      0.171      -0.034       0.189
# ==============================================================================
# Omnibus:                     1180.293   Durbin-Watson:                   1.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.952
# Skew:                           0.760   Prob(JB):                     3.17e-12
# Kurtosis:                       1.607   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of platelets with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7189
# Date:                Thu, 20 May 2021   Prob (F-statistic):              0.397
# Time:                        21:03:05   Log-Likelihood:                -196.16
# No. Observations:                 299   AIC:                             396.3
# Df Residuals:                     297   BIC:                             403.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3830      0.078      4.920      0.000       0.230       0.536
# platelets   -2.35e-07   2.77e-07     -0.848      0.397    -7.8e-07     3.1e-07
# ==============================================================================
# Omnibus:                     1607.910   Durbin-Watson:                   1.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.705
# Skew:                           0.764   Prob(JB):                     2.18e-12
# Kurtosis:                       1.594   Cond. No.                     8.08e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ANOVA of serum_creatinine with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     28.16
# Date:                Thu, 20 May 2021   Prob (F-statistic):           2.19e-07
# Time:                        21:03:05   Log-Likelihood:                -182.98
# No. Observations:                 299   AIC:                             370.0
# Df Residuals:                     297   BIC:                             377.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.1356      0.043      3.119      0.002       0.050       0.221
# serum_creatinine     0.1330      0.025      5.306      0.000       0.084       0.182
# ==============================================================================
# Omnibus:                      135.444   Durbin-Watson:                   1.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.090
# Skew:                           0.763   Prob(JB):                     1.62e-10
# Kurtosis:                       1.863   Cond. No.                         3.60
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of serum_sodium with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     11.77
# Date:                Thu, 20 May 2021   Prob (F-statistic):           0.000689
# Time:                        21:03:05   Log-Likelihood:                -190.72
# No. Observations:                 299   AIC:                             385.4
# Df Residuals:                     297   BIC:                             392.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        3.1478      0.825      3.818      0.000       1.525       4.770
# serum_sodium    -0.0207      0.006     -3.430      0.001      -0.033      -0.009
# ==============================================================================
# Omnibus:                      274.192   Durbin-Watson:                   1.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.269
# Skew:                           0.741   Prob(JB):                     5.44e-11
# Kurtosis:                       1.736   Cond. No.                     4.24e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ANOVA of sex with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                  0.005534
# Date:                Thu, 20 May 2021   Prob (F-statistic):              0.941
# Time:                        21:03:05   Log-Likelihood:                -196.52
# No. Observations:                 299   AIC:                             397.0
# Df Residuals:                     297   BIC:                             404.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3238      0.046      7.083      0.000       0.234       0.414
# sex           -0.0042      0.057     -0.074      0.941      -0.116       0.107
# ==============================================================================
# Omnibus:                     1979.060   Durbin-Watson:                   1.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.130
# Skew:                           0.766   Prob(JB):                     1.76e-12
# Kurtosis:                       1.588   Cond. No.                         3.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of smoking with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.04733
# Date:                Thu, 20 May 2021   Prob (F-statistic):              0.828
# Time:                        21:03:05   Log-Likelihood:                -196.50
# No. Observations:                 299   AIC:                             397.0
# Df Residuals:                     297   BIC:                             404.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3251      0.033      9.889      0.000       0.260       0.390
# smoking       -0.0126      0.058     -0.218      0.828      -0.127       0.102
# ==============================================================================
# Omnibus:                     1952.463   Durbin-Watson:                   1.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.103
# Skew:                           0.766   Prob(JB):                     1.78e-12
# Kurtosis:                       1.588   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ANOVA of time with DEATH_EVENT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   R-squared:                       0.278
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     114.2
# Date:                Thu, 20 May 2021   Prob (F-statistic):           9.12e-23
# Time:                        21:03:05   Log-Likelihood:                -147.89
# No. Observations:                 299   AIC:                             299.8
# Df Residuals:                     297   BIC:                             307.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7347      0.045     16.313      0.000       0.646       0.823
# time          -0.0032      0.000    -10.686      0.000      -0.004      -0.003
# ==============================================================================
# Omnibus:                       21.239   Durbin-Watson:                   1.506
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.641
# Skew:                           0.452   Prob(JB):                     0.000401
# Kurtosis:                       2.338   Cond. No.                         296.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
